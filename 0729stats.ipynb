# %% [markdown]
# # two types
#
# descriptive -  central tendency : mean median mode ; Variability: sd variance range
# inferential -  confidence interval & margin of error

# %% [markdown]
# # basic stat terms
# population
# sample
# variable
# data (singular, plural)
# experiment
# parameter
# statistic

# %% [markdown]
# # 2 types of data
# categorical -  qualitative data - nominal / ordinal
# numerical -  quantitative data - discrete(countable) data / continous data
#
# interval: degree Celsius (0 has meaning)
# ratio : contains absolute value

# %% [markdown]
# # measures of central tendency
# mode median mean
# "center point" "average"
#
# median : not affected by outliers
#
# consider median most!

# %% [markdown]
# # S2 S
# variance "how far is each value from the mean"      square(make everything positve) S2
# standard deviation, square root of the variance     S
#
# symmetrical and asymmetrical distribution
# bell curver
# normal distribution: mean= mode = median
#
# asymmetrical distribution: left skewed(exam results in class), right skewed(salaries within a company)
#
# # use skewness to find outliers,
# or
# # interquartile range:  lower bound, upper bound - boxplot - find outliers
#
# Z score  - can use to compare different things : ml, lb, g, kg...
# z= (x- mean) / sd
#
# # handling outlier is the major thing before training the model
# if it is okay to eliminate outlier
# or if it is not okay to eliminate outlier
# capping : replace the extreme values with the max/min value
# binning : classify the data into groups, eliminate the group

# %% [markdown]
# # probability density function
# like tossing a coin, 50% 50% probability
#
# normal distribution         68% 1st sd,      95% 2nd sd,    99.7 3rd sd
#
# bernoulli's distribution     One trial binary output: toss a coin, true or false, 0 or 1
# binomial distribution        Many Bernoulli trials
#
# uniform distribution         roll a dice, equal probability,Every outcome is equally likely
#
# poisson distribution         Count events in time or space

# %% [markdown]
# # Central Limit Theorem
# Take a large enough sample out of a population, it will approach normal distribution
# And the ditribution of the original population dataset does not matter, can be not normally ditributed
# But the sample mean will be normal distribution

# %% [markdown]
# z test
# t test
# chi square test - categorical variable
# anova test
