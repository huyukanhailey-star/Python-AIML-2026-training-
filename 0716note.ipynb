# %% [markdown]
# -- 0716 note Python
# Difference bt SQL & Python: SQL is for querying data, to fetch data in the database
# Python: high level language, dynamically typed, multiparadigm
#
#
#
# - 4 types: str '' "" ; Int ; Float; Boolean(True or False)
#
# can only concatenate str to str
#
# - Type casting: change the data type
# 1.	Implicit :
# 2.	Explicit  you manually change it
#
#
# - Naming convention for variables
# 1. should not start with number
# 2. should not start with special characters
# 3. should not use python inbuilt function names
#
# = assign, == equal
# a variable is defined through assignment =
#
# Operators in Python
# + - * / % ** //
#
# Comparison operations TRUE FALSE
#
# Logical operations
# x = True
# y = False
# print (x and y)
# print(x or y)
# print (not y)
# False
# True
# True
#
#
# Assigment operations
# x= 5
# x-=15         --  means  x= x-15
# print(x)
# -10
#
# x* = 3
# x+ = 3
#
#
# name = str (input(“Enter your name:”))
# print("Hello", name)
# print(type(name))
# Enter your name: jim
# Hello jim
# <class 'str'>
#
#
# f string
# age =52
# type(age)
# year = 1978
# x = f"I am {age} years old, born in {year}"
# print(x)
# I am 52 years old, born in 1978
#
# .format
# language = "python"
# subject = ‘coding’
# print("I love {}, my subject is {}" .format(language, subject))
# I love python, my subject is coding
#
#
# - Branching: if elif else
# nested if
#
# i =4
# if (i<3):
#     print('omg')
#     if i<2:
#     print('omggg')
# elif i<5:
#     print('ha')
# elif i<12:
#     print ('haha')
# else:
#     print('bye')
#
# ha
