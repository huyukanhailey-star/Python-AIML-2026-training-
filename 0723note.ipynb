# %% [markdown]
# # 0723 note
# till now: how to write python, how pyhon works
# now: how to use python
#
# # text file  txt
#
# "w" write mode
# "r" read
# "a" append

# %%
# Writing to a text file

with open (r"/Users/hyk/Desktop/training/0723sample.txt", "w") as f:
    f.write("Hello, this is a sample text file.\n") 
    f.write("It has multiple lines. \n") 
    f.write("hi hello world\n")
    f.write( 'hello this is python testing file operations commands')

# Reading from a text file
with open (r"/Users/hyk/Desktop/training/0723sample.txt", "r") as f:
    content = f.read()
    print("File content:")
    print (content)
# Out:
# File content:
# Hello, this is a sample text file.
# It has multiple lines.
# hi hello world
# hello this is python testing file operations commands

# %%
# read line by line
with open(r"/Users/hyk/Desktop/training/0723sample.txt", "r") as f:
    print ("Line:", f. readline().strip())
    print ("Line:", f. readline().strip())
    print ("Line:", f. readline().strip())
    print ("Line:", f. readline().strip())  
    print ("Line:", f. readline().strip())
# Out:
# Line: Hello, this is a sample text file.
# Line: It has multiple lines.
# Line: hi hello world
# Line: hello this is python testing file operations commandsAppending a new line.
# Line: Enough.

# %%
with open(r"/Users/hyk/Desktop/training/0723sample.txt", "r") as f:
    lines = f.readlines()
    print(lines)    # into a list []
# Out:
# ['Hello, this is a sample text file.\n', 'It has multiple lines. \n', 'hi hello world\n', 'hello this is python testing file operations commandsAppending a new line.\n', 'Enough.\n', 'Appending a new line.\n', 'Enough.\n', 'Appending a new line.\n', 'Enough.\n']

# %%
# append
with open(r"/Users/hyk/Desktop/training/0723sample.txt", "a") as f:
    f.write("Appending a new line.\n")
    f.write("Enough.\n")

with open(r"/Users/hyk/Desktop/training/0723sample.txt", "r") as f:
    print("First 10 characters:", f. read (10))
# Out:
# First 10 characters: Hello, thi

# %%
#copy file
with open ("/Users/hyk/Desktop/training/0723sample.txt", "r") as src, open ("/Users/hyk/Desktop/training/copy_sample.txt", "w") as cop:
    for line in src:
        cop.write(line)

with open(r"/Users/hyk/Desktop/training/copy_sample.txt", "r") as f:
    content = f. read ()
    print("File content:")
    print (content)
# Out:
# File content:
# Hello, this is a sample text file.
# It has multiple lines.
# hi hello world
# hello this is python testing file operations commandsAppending a new line.
# Enough.
# Appending a new line.
# Enough.
# Appending a new line.
# Enough.

# %% [markdown]
# # exel files .xlsx
# # pandas

# %%
import pandas as pd
# Sample datal
data = {
    "Name": ["Alice", "Bob", "Charlie", 'ruchik', 'sushma', 'Thauja', 'max', 'karthik','gibrish'],
    "Marks": [85, 90, 78,87,11,44,0,21,55]
}
df = pd.DataFrame(data)
df
# Writing to an Excel file
df.to_excel("students.xlsx", index=False)
# # Reading from an Excel file
df_read = pd. read_excel("students.xlsx")
print("Data from Excel:")
print(df_read)
# Out:
# Data from Excel:
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78
# 3   ruchik     87
# 4   sushma     11
# 5   Thauja     44
# 6      max      0
# 7  karthik     21
# 8  gibrish     55

# %% [markdown]
# # modules and libraries
#
# built-in modules
# create your own modules
#
# Modules:   a single Python file with multiple functions
# Package:  a folder with module files
# Library: a collection of packages
#
#
# Libraries - packages - modules - functions
#
# .py
#
# Python built-in libraries: pandas  math  random  datetime  os sys statistics

# %% [markdown]
# # Errors and Exception Handling
#
# try except finally
#
# so you won't fail the whole code for some minor issue

# %% [markdown]
# # Database connectivity and operations using Python.
# import sqlite3
