# %% [markdown]
# # Pandas - deal with structured data
# import pandas
#
# data profiling, data analysis
#
# read data describe()
# add column
#
# pandas Series
#
# s = pd.Series([value], index=[index])
# print(s)
#
# default index = 0,1,2...
#
# # ways to create DataFrame
# df = pd.DataFrame({'name': ['Mary','John'], 'age': [28,35]})
# df = pd.DataFrame(matrix_data, row_labels, column_headings)
# df = pd.read_csv("data.csv")
# df = pd.read_sql("SELECT * FROM customer", connection)
#
#
# data = {
#     'Company': ['GOOG','GOOG','MSFT'],
#     'Person': ['Sam','Charlie','Amy'],
#     'Sales': [200,120,340]
# }
# df = pd.DataFrame(data)
# print(df)
#
#     Company   Person  Sales
# 0     GOOG      Sam    200
# 1     GOOG  Charlie    120
# 2     MSFT      Amy    340
#
#
# loc [index name]
# iloc [index]
#
# # NumPY math operation
#
# import numpy
#
# astype(str)
# isnull()
# array[]
#
#
# my_data = [10, 20, 30]   #  [10, 20, 30]
# arr = np.array(my_data)  #  [10 20 30]      (no,)
#
# pd.Series(data, index=labels)
#
#
# import numpy as np
# arr = np.array([10, 20, 30])
# arr * 2
#
# arr = np.array([1, 2, 3, 4, 5])
# print(arr.mean())
# print(arr.sum())
# print(arr.max())
# print(arr.std())
#
# axis = 0, row value
# axis = 1. column value
#
# np.where(titanic_train["Fare"] == max(titanic_train["Fare"]))
# (array([121]),)
#
# titanic_train.iloc[np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))]
#
#
# # OS  find the path of the file
#
# import os
#
# # two dimensional data visualization
#
# import matplotlib.pyplot
#
# import seaborn
#
# # ployly
# cufflinks three dimensional data visualization
#
# # heatmap used to check correlation
